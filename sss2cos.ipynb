# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/repos/preprocessing/corrected_sssd2depth_256x256_cos/thres_0.08_float --name=sssd2cos_256x256_Goteborg_0.08_pnp --model=sss2cos --direction=AtoB \
--niter=400 --niter_decay=200 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=9011 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=0.0 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=32  --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# : 0.016, data: 0.003) TV: 0.000 G_L1: 0.003
# (epoch: 577, iters: 736, time: 0.016, data: 0.003) TV: 0.000 G_L1: 0.003
# (epoch: 577, iters: 896, time: 0.016, data: 0.003) TV: 0.000 G_L1: 0.002
# (epoch: 577, iters: 1056, time: 0.016, data: 0.003) TV: 0.000 G_L1: 0.003
# saving the model at the end of epoch 577, iters 683168
# (epoch: 577, iters: 1184, time: 0.016, data: 0.003) abs_rel: -0.013 sq_rel: 0.000 rmse: 0.007 rmse_log10: nan mae: 0.006 mae_log10: nan a1: 0.989 a2: 1.000 a3: 1.000
# End of epoch 577 / 600 	 Time Taken: 15 sec
# learning rate = 0.0000229
# (epoch: 578, iters: 32, time: 0.077, data: 0.003) TV: 0.000 G_L1: 0.003
# (epoch: 578, iters: 192, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.003
# (epoch: 578, iters: 352, time: 0.016, data: 0.006) TV: 0.000 G_L1: 0.003
# (epoch: 578, iters: 512, time: 0.016, data: 0.002) TV: 0.000 G_L1: 0.003
# (epoch: 578, iters: 672, time: 0.016, data: 0.002) TV: 0.000 G_L1: 0.003
# ...

# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/repos/preprocessing/corrected_sssd2depth_256x256_cos/thres_sl_appro_d_0.08_float --name=sssd2cos_256x256_Goteborg_0.08_pnp_sl_d --model=sss2cos --direction=AtoB \
--niter=200 --niter_decay=200 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=9011 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=0.0 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=32  --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# h: 377, iters: 576, time: 0.016, data: 0.003) TV: 0.000 G_L1: 0.002
# (epoch: 377, iters: 736, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 377, iters: 896, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 377, iters: 1056, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.002
# saving the model at the end of epoch 377, iters 446368
# (epoch: 377, iters: 1184, time: 0.016, data: 0.004) abs_rel: 0.017 sq_rel: 0.000 rmse: 0.545 rmse_log10: inf mae: 0.280 mae_log10: inf a1: 0.978 a2: 0.996 a3: 0.997
# End of epoch 377 / 400 	 Time Taken: 13 sec
# learning rate = 0.0000229
# (epoch: 378, iters: 32, time: 0.056, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 378, iters: 192, time: 0.016, data: 0.008) TV: 0.000 G_L1: 0.002
# (epoch: 378, iters: 352, time: 0.016, data: 0.003) TV: 0.000 G_L1: 0.002
# (epoch: 378, iters: 512, time: 0.016, data: 0.003) TV: 0.000 G_L1: 0.002
# (epoch: 378, iters: 672, time: 0.016, data: 0.005) TV: 0.000 G_L1: 0.002
# ...

# %%
# !python test_sssc2cos_m2m_pnp.py  --dataroot=/home/yipingx/repos/preprocessing/corrected_sssd2depth_256x256_cos/thres_sl_appro_d_0.08_float --direction=AtoB --model=sss2cos --name=sssd2cos_256x256_Goteborg_0.08_pnp_sl_d  --output_nc=1 --ngf=32  --no_flip --no_dropout --epoch=best --input_nc=2 --num_threads=8 --num_test=2000 --netG=resnet_7blocks_pnp --dataset_mode=alignedm2md --phase=test --pnp_iters=1
# Out:
# x256_cos/thres_sl_appro_d_0.08_float	[default: None]
#              dataset_mode: alignedm2md                   	[default: aligned]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: best                          	[default: latest]
#                      eval: True
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 2                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                    is_pnp: False
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: sss2cos                       	[default: test]
#                n_layers_D: 3
#                      name: sssd2cos_256x256_Goteborg_0.08_pnp_sl_d	[default: experiment_name]
#                       ndf: 64
# ...

# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/repos/preprocessing/corrected_sssd2depth_256x256_cos/thres_sl_appro_d_0.08_float --name=sssd2cos_256x256_Goteborg_0.08_pnp_sl_d_ngf16_ndf32 --model=sss2cos --direction=AtoB \
--niter=200 --niter_decay=300 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=9011 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=0.0 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=16  --ndf=32 --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# (epoch: 477, iters: 576, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.003
# (epoch: 477, iters: 736, time: 0.010, data: 0.005) TV: 0.000 G_L1: 0.002
# (epoch: 477, iters: 896, time: 0.010, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 477, iters: 1056, time: 0.010, data: 0.004) TV: 0.000 G_L1: 0.002
# saving the model at the end of epoch 477, iters 564768
# (epoch: 477, iters: 1184, time: 0.010, data: 0.005) abs_rel: 0.015 sq_rel: 0.000 rmse: 0.513 rmse_log10: inf mae: 0.249 mae_log10: inf a1: 0.991 a2: 0.997 a3: 0.997
# End of epoch 477 / 500 	 Time Taken: 10 sec
# learning rate = 0.0000153
# (epoch: 478, iters: 32, time: 0.062, data: 0.005) TV: 0.000 G_L1: 0.003
# (epoch: 478, iters: 192, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 478, iters: 352, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 478, iters: 512, time: 0.011, data: 0.003) TV: 0.000 G_L1: 0.002
# (epoch: 478, iters: 672, time: 0.011, data: 0.006) TV: 0.000 G_L1: 0.002
# ...

# %%
# !python test_sssc2cos_m2m_pnp.py  --dataroot=/home/yipingx/repos/preprocessing/corrected_sssd2depth_256x256_cos/thres_sl__d_0.08_float --direction=AtoB --model=sss2cos --name=sssd2cos_256x256_Goteborg_0.08_pnp_sl_d_ngf16_ndf32  --output_nc=1 --ngf=16 --ndf=32  --no_flip --no_dropout --epoch=best --input_nc=2 --num_threads=8 --num_test=2000 --netG=resnet_7blocks_pnp --dataset_mode=alignedm2md --phase=test --pnp_iters=1
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: /home/yipingx/repos/preprocessing/corrected_sssd2depth_256x256_cos/thres_sl_d_0.08_float	[default: None]
#              dataset_mode: alignedm2md                   	[default: aligned]
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: best                          	[default: latest]
#                      eval: True
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 2                             	[default: 3]
#                   isTrain: False                         	[default: None]
#                    is_pnp: False
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
# ...

# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/repos/preprocessing/corrected_sssd2depth_256x256_cos/thres_sl_d_0.08_float --name=sssd2cos_256x256_Goteborg_0.08_pnp_realsl_d_ngf16_ndf32 --model=sss2cos --direction=AtoB \
--niter=200 --niter_decay=300 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=9011 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=0.0 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=16  --ndf=32 --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# 7, iters: 736, time: 0.010, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 477, iters: 896, time: 0.010, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 477, iters: 1056, time: 0.010, data: 0.004) TV: 0.000 G_L1: 0.002
# saving the model at the end of epoch 477, iters 564768
# (epoch: 477, iters: 1184, time: 0.010, data: 0.004) abs_rel: 0.016 sq_rel: 0.000 rmse: 0.311 rmse_log10: 0.008 mae: 0.260 mae_log10: 0.007 a1: 0.962 a2: 1.000 a3: 1.000
# End of epoch 477 / 500 	 Time Taken: 10 sec
# learning rate = 0.0000153
# (epoch: 478, iters: 32, time: 0.062, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 478, iters: 192, time: 0.010, data: 0.008) TV: 0.000 G_L1: 0.002
# (epoch: 478, iters: 352, time: 0.010, data: 0.003) TV: 0.000 G_L1: 0.002
# (epoch: 478, iters: 512, time: 0.010, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 478, iters: 672, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.002
# (epoch: 478, iters: 832, time: 0.010, data: 0.004) TV: 0.000 G_L1: 0.002
# ...

# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float --name=sssd2cos_256x256_20190626_Mission_8_0.25_pnp_realsl_d_ngf16_ndf32_cos --model=sss2cos --direction=AtoB \
--niter=200 --niter_decay=300 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=8097 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=0.0 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=16  --ndf=32 --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# ters: 576, time: 0.011, data: 0.003) TV: 0.000 G_L1: 0.012
# (epoch: 40, iters: 736, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.008
# (epoch: 40, iters: 896, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.014
# (epoch: 40, iters: 1056, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.012
# (epoch: 40, iters: 1216, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.009
# (epoch: 40, iters: 1376, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.009
# saving the latest model (epoch 40, total_iters 80000)
# (epoch: 40, iters: 1536, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.008
# (epoch: 40, iters: 1696, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.011
# (epoch: 40, iters: 1856, time: 0.011, data: 0.004) TV: 0.000 G_L1: 0.010
# (epoch: 40, iters: 2016, time: 0.007, data: 0.004) TV: 0.000 G_L1: 0.012
# saving the model at the end of epoch 40, iters 80640
# ...

# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float --name=sssd2cos_256x256_20190626_Mission_8_0.25_pnp_realsl_d_ngf16_ndf32_depth --model=sss2cos --direction=AtoB \
--niter=200 --niter_decay=300 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=8097 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=0.0 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=16  --ndf=32 --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# 552 a3: 0.605
# End of epoch 484 / 500 	 Time Taken: 14 sec
# learning rate = 0.0000106
# (epoch: 485, iters: 96, time: 0.065, data: 0.004) TV: 0.000 G_L1: 8.608
# (epoch: 485, iters: 256, time: 0.065, data: 0.003) TV: 0.000 G_L1: 8.061
# (epoch: 485, iters: 416, time: 0.010, data: 0.005) TV: 0.000 G_L1: 7.710
# (epoch: 485, iters: 576, time: 0.011, data: 0.004) TV: 0.000 G_L1: 7.623
# (epoch: 485, iters: 736, time: 0.011, data: 0.004) TV: 0.000 G_L1: 7.216
# (epoch: 485, iters: 896, time: 0.010, data: 0.004) TV: 0.000 G_L1: 9.450
# (epoch: 485, iters: 1056, time: 0.011, data: 0.004) TV: 0.000 G_L1: 6.739
# (epoch: 485, iters: 1216, time: 0.011, data: 0.004) TV: 0.000 G_L1: 8.556
# (epoch: 485, iters: 1376, time: 0.011, data: 0.005) TV: 0.000 G_L1: 6.902
# (epoch: 485, iters: 1536, time: 0.010, data: 0.004) TV: 0.000 G_L1: 8.393
# (epoch: 485, iters: 1696, time: 0.010, data: 0.004) TV: 0.000 G_L1: 7.253
# (epoch: 485, iters: 1856, time: 0.011, data: 0.004) TV: 0.000 G_L1: 8.431
# ...

# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float --name=sssd2cos_256x256_20190626_Mission_8_0.25_pnp_realsl_d_ngf32_ndf64_depth --model=sss2cos --direction=AtoB \
--niter=200 --niter_decay=300 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=8097 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=0.0 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=32  --ndf=64 --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# ime: 0.016, data: 0.004) TV: 0.000 G_L1: 0.069
# (epoch: 325, iters: 1376, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.110
# (epoch: 325, iters: 1536, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.104
# (epoch: 325, iters: 1696, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.093
# (epoch: 325, iters: 1856, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.080
# (epoch: 325, iters: 2016, time: 0.010, data: 0.005) TV: 0.000 G_L1: 0.117
# saving the model at the end of epoch 325, iters 655200
# (epoch: 325, iters: 2016, time: 0.010, data: 0.005) abs_rel: 0.030 sq_rel: 0.000 rmse: 0.734 rmse_log10: 0.016 mae: 0.585 mae_log10: 0.013 a1: 0.844 a2: 0.971 a3: 0.988
# End of epoch 325 / 500 	 Time Taken: 23 sec
# learning rate = 0.0001163
# (epoch: 326, iters: 160, time: 0.053, data: 0.282) TV: 0.000 G_L1: 0.082
# (epoch: 326, iters: 320, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.117
# (epoch: 326, iters: 480, time: 0.016, data: 0.003) TV: 0.000 G_L1: 0.104
# ...

# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float --name=sssd2cos_256x256_20190626_Mission_8_0.25_pnp_realsl_d_ngf32_ndf64_depth_tv0.1 --model=sss2cos --direction=AtoB \
--niter=200 --niter_decay=300 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=8097 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=0.1 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=32  --ndf=64 --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# 533 mae_log10: 0.012 a1: 0.857 a2: 0.955 a3: 0.983
# End of epoch 484 / 500 	 Time Taken: 23 sec
# learning rate = 0.0000106
# (epoch: 485, iters: 96, time: 0.071, data: 0.004) TV: 0.001 G_L1: 0.062
# (epoch: 485, iters: 256, time: 0.071, data: 0.003) TV: 0.001 G_L1: 0.053
# (epoch: 485, iters: 416, time: 0.016, data: 0.005) TV: 0.001 G_L1: 0.070
# (epoch: 485, iters: 576, time: 0.016, data: 0.005) TV: 0.000 G_L1: 0.064
# (epoch: 485, iters: 736, time: 0.016, data: 0.005) TV: 0.001 G_L1: 0.063
# (epoch: 485, iters: 896, time: 0.016, data: 0.004) TV: 0.001 G_L1: 0.048
# (epoch: 485, iters: 1056, time: 0.016, data: 0.004) TV: 0.000 G_L1: 0.058
# (epoch: 485, iters: 1216, time: 0.016, data: 0.004) TV: 0.001 G_L1: 0.066
# (epoch: 485, iters: 1376, time: 0.016, data: 0.004) TV: 0.001 G_L1: 0.053
# (epoch: 485, iters: 1536, time: 0.016, data: 0.004) TV: 0.001 G_L1: 0.069
# (epoch: 485, iters: 1696, time: 0.016, data: 0.004) TV: 0.001 G_L1: 0.058
# ...

# %%
# !python test_sssc2cos_m2m_pnp.py  --dataroot=/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float --direction=AtoB --model=sss2cos --name=sssd2cos_256x256_20190626_Mission_8_0.25_pnp_realsl_d_ngf32_ndf64_depth_tv0.1  --output_nc=1 --ngf=32  --no_flip --no_dropout --epoch=best --input_nc=2 --num_threads=8 --num_test=2000 --netG=resnet_7blocks_pnp --dataset_mode=alignedm2md --phase=test --pnp_iters=1
# Out:
# /meas_data/corrected_sssd2depth_256x256/thres_0.25_float/test/125.npy']
# processing (0031)-th image... ['/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float/test/126.npy']
# processing (0032)-th image... ['/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float/test/127.npy']
# processing (0033)-th image... ['/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float/test/128.npy']
# processing (0034)-th image... ['/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float/test/129.npy']
# processing (0035)-th image... ['/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float/test/13.npy']
# ...

# %%
# !python train_sssc2cos_m2m.py --dataroot=/home/yipingx/Data/20190626_Mission_8/pp/cereal_file/meas_data/corrected_sssd2depth_256x256/thres_0.25_float --name=sssd2cos_256x256_20190626_Mission_8_0.25_pnp_realsl_d_ngf32_ndf64_depth_tv1.0 --model=sss2cos --direction=AtoB \
--niter=100 --niter_decay=300 --batch_size=32 --preprocess=none --input_nc=2 --output_nc=1 --num_threads=8 --display_server=localhost \
--display_port=8097 --max_dataset_size=100000 --display_id=1 --display_freq=10 --print_freq=10 --save_epoch_freq=1 --lambda_TV=10.0 --load_size=256 \
--no_flip --no_dropout --beta1=0.9 --ngf=32  --ndf=64 --netG=resnet_7blocks_pnp \
--dataset_mode=alignedm2md  --display_ncols=5
# Out:
# e: 0.607 mae_log10: 0.013 a1: 0.834 a2: 0.948 a3: 0.979
# End of epoch 384 / 400 	 Time Taken: 23 sec
# learning rate = 0.0000106
# (epoch: 385, iters: 96, time: 0.060, data: 0.005) TV: 0.003 G_L1: 0.052
# (epoch: 385, iters: 256, time: 0.016, data: 0.003) TV: 0.003 G_L1: 0.100
# (epoch: 385, iters: 416, time: 0.016, data: 0.010) TV: 0.003 G_L1: 0.069
# (epoch: 385, iters: 576, time: 0.016, data: 0.003) TV: 0.003 G_L1: 0.074
# (epoch: 385, iters: 736, time: 0.017, data: 0.004) TV: 0.003 G_L1: 0.065
# (epoch: 385, iters: 896, time: 0.016, data: 0.005) TV: 0.003 G_L1: 0.075
# (epoch: 385, iters: 1056, time: 0.016, data: 0.005) TV: 0.004 G_L1: 0.098
# (epoch: 385, iters: 1216, time: 0.016, data: 0.004) TV: 0.003 G_L1: 0.084
# (epoch: 385, iters: 1376, time: 0.016, data: 0.005) TV: 0.003 G_L1: 0.056
# (epoch: 385, iters: 1536, time: 0.016, data: 0.004) TV: 0.003 G_L1: 0.056
# (epoch: 385, iters: 1696, time: 0.016, data: 0.004) TV: 0.004 G_L1: 0.075
# ...
